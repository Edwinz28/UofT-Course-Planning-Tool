# %% [markdown]
# # Course Notebook
#
# For checking out course.csv and ece_course.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('./courses.csv')
df.head()
# Out:
#    Unnamed: 0      Code                                               Name  \
# 0           0  ENGB29H3                               Shakespeare and Film
# 1           1  JMU421H1         Advanced Jazz Arranging & Orchestration II
# 2           2  PSY220H5                  Introduction to Social Psychology
# 3           3  ARC382H1  Structures, Building Systems, and Environments II
# 4           4  ACMC01H3                           ACMEE Applied Practice I
#
#                                             Division  \
# 0                  University of Toronto Scarborough
# 1                                   Faculty of Music
# 2                  University of Toronto Mississauga
# 3  John H. Daniels Faculty of Architecture, Lands...
# 4                  University of Toronto Scarborough
#
#                                   Course Description  \
# 0  The history of Shakespeare and (on) film is lo...
# 1                          Continuation of JMU420H1.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4698 entries, 0 to 4697
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     4698 non-null   int64
#  1   Code                           4698 non-null   object
#  2   Name                           4698 non-null   object
#  3   Division                       4698 non-null   object
#  4   Course Description             4624 non-null   object
#  5   Department                     4698 non-null   object
#  6   Pre-requisites                 4698 non-null   object
#  7   Course Level                   4698 non-null   int64
#  8   UTSC Breadth                   1251 non-null   object
#  9   APSC Electives                 1793 non-null   object
#  10  Campus                         4698 non-null   object
#  11  Term                           4698 non-null   object
# ...

# %%
ece_df = pd.read_csv('./ece_courses.csv')
ece_df.head()
# Out:
#    Unnamed: 0      Code                               Name  \
# 0          11  ECE557H1              Linear Control Theory
# 1          13  ECE344H1                  Operating Systems
# 2          96  ECE297H1  Software Design and Communication
# 3         119  ECE345H1     Algorithms and Data Structures
# 4         139  ECE334H1                Digital Electronics
#
#                                    Division  \
# 0  Faculty of Applied Science & Engineering
# 1  Faculty of Applied Science & Engineering
# 2  Faculty of Applied Science & Engineering
# 3  Faculty of Applied Science & Engineering
# 4  Faculty of Applied Science & Engineering
#
#                                   Course Description  \
# 0  State-space approach to linear system theory. ...
# 1  Operating system structures, concurrency, sync...
# 2  An introduction to engineering design processe...
# 3  Design and analysis of algorithms and data str...
# 4  Digital design techniques for integrated circu...
#
# ...

# %%
ece_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     81 non-null     int64
#  1   Code                           81 non-null     object
#  2   Name                           81 non-null     object
#  3   Division                       81 non-null     object
#  4   Course Description             81 non-null     object
#  5   Department                     81 non-null     object
#  6   Pre-requisites                 81 non-null     object
#  7   Course Level                   81 non-null     int64
#  8   UTSC Breadth                   0 non-null      float64
#  9   APSC Electives                 1 non-null      object
#  10  Campus                         81 non-null     object
#  11  Term                           81 non-null     object
# ...
